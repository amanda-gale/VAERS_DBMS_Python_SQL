# %%
from dotenv import load_dotenv
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
load_dotenv()   # fetch environment variable
engine = create_engine(os.getenv("VAERS_DATABASE_URL"))    # create engine from env

# %%
query = """SELECT COUNT(*) FROM symptoms_2025"""

# %%
pd.read_sql_query(query, engine)
# Out:
#    count
# 0  49044

# %%
query = """SELECT COUNT(DISTINCT("VAERS_ID")) FROM symptoms_2025"""

# %%
pd.read_sql_query(query, engine)
# Out:
#    count
# 0  40285

# %%
query = """"""
